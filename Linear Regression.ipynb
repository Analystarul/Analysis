# %% [markdown]
# ### 1.Importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.Reading the dataset

# %%
import pandas as pd
df = pd.read_csv("Ice Cream.csv")

# %%
df
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %% [markdown]
# ### 3.Checking for missing values

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# ### 4.Visualization of data

# %%
import seaborn as sns
sns.jointplot(x="Temperature",y="Revenue",data=df)

# %% [markdown]
# ### 5. Splitting the dataset

# %%
x = df[["Temperature"]].values #2D array ,Independent variable
y = df["Revenue"].values #1D array ,Dependent Variable

# %%
x.shape,y.shape
# Out:
# ((500, 1), (500,))

# %%
x
# Out:
# array([[24.6],
#        [26.1],
#        [27.8],
#        [20.6],
#        [11.6],
#        [14.4],
#        [13.8],
#        [30.9],
#        [ 1. ],
#        [31.7],
#        [11.5],
#        [ 3.7],
#        [18.9],
#        [13.7],
#        [39.6],
#        [18.5],
#        [26. ],
#        [42.6],
#        [29.6],
#        [21.8],
#        [25.5],
#        [15.3],
#        [22.7],
#        [16.3],
#        [23.9],
#        [19. ],
#        [15.7],
#        [29.2],
#        [19.1],
#        [35.2],
#        [24.2],
#        [15.3],
#        [ 8.8],
#        [18.3],
#        [35.7],
#        [37.1],
#        [22.3],
#        [17.6],
#        [31.8],
#        [17.1],
#        [23.1],
#        [ 8.8],
#        [18.8],
#        [14.2],
#        [18.7],
#        [15.7],
#        [21. ],
#        [30.7],
#        [20.5],
#        [31.3],
#        [ 6.4],
#        [27.2],
#        [28.7],
#        [28. ],
#        [10.4],
#        [27.4],
#        [33.3],
#        [36.6],
# ...

# %%
y
# Out:
# array([ 535,  626,  661,  488,  317,  368,  309,  697,   56,  738,  326,
#          72,  468,  290,  906,  470,  649,  922,  650,  535,  613,  354,
#         525,  375,  524,  474,  403,  680,  518,  810,  529,  357,  238,
#         419,  810,  871,  551,  406,  741,  502,  540,  243,  422,  359,
#         468,  397,  501,  652,  452,  698,  191,  622,  667,  629,  220,
#         624,  750,  828,  304,  352,  382,  322,  775,  132,  499,  196,
#         497,  285,  484,  431,  277,  628,  644,  624,  587,  654,  919,
#         592,  652,  683,  373,  382,  516,  686,  655,  407,  644,  345,
#         643,  362,  705,  223,  544,  222,  338,  213,  475,  461,  344,
#         284,  469,  712,  323,  402,  628,  416,  554,  363,  644,  652,
#         604,  428,  566,  734,  386,  690,  573,  720,  307,  597,  541,
#         342,  656,  703,  320,  451,  383,  675,  732,  752,  497,  418,
#         449,  478,  159,  517,  600,  657,  508,  280,  842,  484,  740,
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split #function

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=2) # Train --> 80%, test --> 20%

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((400, 1), (100, 1), (400,), (100,))

# %% [markdown]
# ### 6. Train the model

# %%
from sklearn.linear_model import LinearRegression #class
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### y = mx+c

# %% [markdown]
# m--> slope, c--> y intercept

# %%
print("Intercept value : ",regressor.intercept_)
# Out:
# Intercept value :  46.19065783225409

# %%
print("Slope value(a) : ",regressor.coef_)
# Out:
# Slope value(a) :  [21.37960235]

# %% [markdown]
# ### y = 21.37x + 46.19

# %%
y_train_pred = regressor.predict(x_train)

# %%
y_train_pred.shape
# Out:
# (400,)

# %%
y_train.shape
# Out:
# (400,)

# %% [markdown]
# ### 7.Visualize the train results

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color="red")
plt.xlabel("Temperature")
plt.ylabel("Revenue")
plt.title("Relationship between Temperature and Revenue")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,y_train_pred,color="black")
plt.xlabel("Temperature")
plt.ylabel("Revenue")
plt.title("Regression line")
plt.show()

# %% [markdown]
# ### 8.Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error,mean_sqaured_error,r2_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 from sklearn.metrics import mean_absolute_error,mean_sqaured_error,r2_score
#
# ImportError: cannot import name 'mean_sqaured_error' from 'sklearn.metrics' (C:\Users\Arulkumar\anaconda3\Lib\site-packages\sklearn\metrics\__init__.py)
